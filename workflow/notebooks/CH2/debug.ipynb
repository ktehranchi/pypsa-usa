# %%
import pypsa
import pandas as pd
import numpy as np

# %%
network_ID = pypsa.Network('/Users/kamrantehranchi/Local_Documents/pypsa-usa/workflow/notebooks/CH2/5_5_BAU/elec_s210_cl7a_ch180a_ec_lv1.0_3h_E_mapped.nc')
# Out:
# WARNING:pypsa.io:Importing network from PyPSA version v0.30.2 while current version is v0.33.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.io:Imported network elec_s210_cl7a_ch180a_ec_lv1.0_3h_E_mapped.nc has buses, carriers, generators, global_constraints, lines, loads, storage_units

# %%
network_ID.generators
# Out:
#                            bus control type   p_nom  p_nom_mod  \
# Generator
# p600 0 CCGT existing    p600 0   Slack        383.9        0.0
# p600 0 OCGT existing    p600 0                  1.2        0.0
# p600 0 oil              p600 0                536.4        0.0
# p600 0 onwind existing  p600 0               4676.7        0.0
# p600 0 solar existing   p600 0               1542.7        0.0
# ...                        ...     ...  ...     ...        ...
# p670 5 load             p670 5      PQ          0.0        0.0
# p670 6 load             p670 6      PQ          0.0        0.0
# p670 7 load             p670 7      PQ          0.0        0.0
# p670 8 load             p670 8      PQ          0.0        0.0
# p670 9 load             p670 9      PQ          0.0        0.0
#
#                         p_nom_extendable  p_nom_min  p_nom_max  p_min_pu  \
# Generator
# p600 0 CCGT existing                True        0.0      383.9       0.0
# ...
